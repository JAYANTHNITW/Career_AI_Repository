# %% [markdown]
# <a href="https://colab.research.google.com/github/JAYANTHNITW/Career_AI_Repository/blob/main/session_4_task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###`Problem 1:` Combine two lists index-wise(columns wise)
#
# Write a program to add two lists index-wise. Create a new list that contains the 0th index item from both the list, then the 1st index item, and so on till the last element. any leftover items will get added at the end of the new list.
#
# `Given List:`
# ```
# list1 = ["M", "na", "i", "Kh"]
# list2 = ["y", "me", "s", "an"]
# ```
#
# `Output:`
# ```
# [['M','y'], ['na', me'], ['i', 's'], ['Kh', 'an']]
# ```

# %%
# Write code here
list1 = ["M", "na", "i", "Kh",'l']
list2 = ["y", "me", "s", "an",]

[list(pair) for pair in list(zip(list1,list2))]
# Out:
# [['M', 'y'], ['na', 'me'], ['i', 's'], ['Kh', 'an']]

# %% [markdown]
# ### `Problem 2:` Add new item to list after a specified item
# Write a program to add item 7000 after 6000 in the following Python List
# ```
# list1 = [10, 20, [300, 400, [5000, 6000], 500], 30, 40]
# ```
# `Output:`
# ```
# [10, 20, [300, 400, [5000, 6000, 7000], 500], 30, 40]
# ```

# %%
# Write code here
list1 = [10, 20, [300, 400, [5000, 6000], 500], 30, 40]
list1[2][2].append(7000)

# %%
list1
# Out:
# [10, 20, [300, 400, [5000, 6000, 7000], 500], 30, 40]

# %% [markdown]
# ###`Problem 3:` Update no of items available
#
# Suppose you are given a list of candy and another list of same size representing no of items of respective candy.
#
# i.e -
# ```
# candy_list = ['Jelly Belly','Kit Kat','Double Bubble','Milky Way','Three Musketeers']
# no_of_items = [10,20,34,74,32]
# ```
#
# Write a program to show no. of items of each candy type.
#
# `Output:`
#
# ```
# Jelly Belly-10
# Kit Kat-20
# Double Bubble-34
# Milky Way-74
# Three Musketeers-32
#
# ```

# %%
# Write code here
candy_list = ['Jelly Belly','Kit Kat','Double Bubble','Milky Way','Three Musketeers']
no_of_items = [10,20,34,74,32]
for item in zip(candy_list,no_of_items):
  print(item[0],item[1],sep='-',end='\n')
# Out:
# Jelly Belly-10
# Kit Kat-20
# Double Bubble-34
# Milky Way-74
# Three Musketeers-32

# %% [markdown]
# ###`Problem 4:` Running Sum on list
# Write a program to print a list after performing running sum on it.
#
# i.e:
#
# `Input:`
# ```
# list1 = [1,2,3,4,5,6]
# ```
# `Output:`
# ```
# [1,3,6,10,15,21]
# ```

# %%
# Write code here
list1 = [1,2,3,4,5,6]
new_list = []
sum = 0

for i in list1:
  sum+=i
  new_list.append(sum)

new_list
# Out:
# [1, 3, 6, 10, 15, 21]

# %% [markdown]
# ###`Problem 5:` You are given a list of integers. You are asked to make a list by running through elements of the list by adding all elements greater and itself.
#
# i.e. Say given list is `[2,4,6,10,1]`
# resultant list will be `[22,20,10,23]`.
#
# For 1st element `2` ->> these are greater `(4+6+10)` values and `2` itself so on adding becomes `22`.
#
# For 2nd element `4` ->> greater elements are `(6, 10)` and `4` itself, so on adding `20`
#
# like wise for all other elememts.
#
# `[2,4,6,10,1]`-->`[22,20,16,10,23]`

# %%
# Write code here
l1 = [2,4,6,10,1]
l2 = []

for i in l1:
  sum = i
  for j in l1:
    if j>i:
      sum+=j

  l2.append(sum)

l2
# Out:
# [22, 20, 16, 10, 23]

# %% [markdown]
# ###`Problem 6:` Find list of common unique items from two list. and show in increasing order
#
# `Input`
#
# ```
# num1 = [23,45,67,78,89,34]
# num2 = [34,89,55,56,39,67]
# ```
#
# `Output:`
# ```
# [34, 67, 89]
# ```

# %%
# Write code he
num1 = [23,45,67,78,89,34]
num2 = [34,89,55,56,39,67]

l = []
for i in num1:
  if i in num2:
    if i not in l:
      l.append(i)

sorted(l)
# Out:
# [34, 67, 89]

# %% [markdown]
# ###`Problem 7:` Sort a list of alphanumeric strings based on product value of numeric character in it. If in any string there is no numeric character take it's product value as 1.
#
# `Input:`
# ```
# ['1ac21', '23fg', '456', '098d','1','kls']
# ```
#
# `Output:`
# ```
# ['456', '23fg', '1ac21', '1', 'kls', '098d']
#
# ```

# %%
# Write code here
l = ['1ac21', '23fg', '456', '098d','1','kls']
prod = []
for i in l:
  p = 1
  for c in i:
    if c.isdigit():
      p*=int(c)
  prod.append(p)
prod

[pair[1] for pair in sorted(list(zip(prod,l)),reverse=True)]
# Out:
# ['456', '23fg', '1ac21', 'kls', '1', '098d']

# %%
list(zip(prod,l))
# Out:
# [(2, '1ac21'), (6, '23fg'), (120, '456'), (0, '098d'), (1, '1'), (1, 'kls')]

# %%
sorted(list(zip(prod,l)),reverse=True)
# Out:
# [(120, '456'), (6, '23fg'), (2, '1ac21'), (1, 'kls'), (1, '1'), (0, '098d')]

# %% [markdown]
# `Problem 8:` Split String of list on K character.
#
# **Example :**
#
# Input:
# ```bash
# ['CampusX is a channel', 'for data-science', 'aspirants.']
# ```
#
# Output:
# ```bash
# ['CampusX', 'is', 'a', 'channel', 'for', 'data-science', 'aspirants.']
# ```

# %%
# Write code here
s = ['CampusX is a channel', 'for data-science', 'aspirants.']
s1 = [item.split() for item in s]
l = []
for i in s1:
  l.extend(i)

l
# Out:
# ['CampusX', 'is', 'a', 'channel', 'for', 'data-science', 'aspirants.']

# %% [markdown]
# ### `Problem 9:` Convert Character Matrix to single String using string comprehension.
#
# **Example 1:**
#
# Input:
# ```bash
# [['c', 'a', 'm', 'p', 'u', 'x'], ['i', 's'], ['b', 'e', 's', 't'], ['c', 'h', 'a', 'n', 'n', 'e', 'l']]
# ```
#
# Output:
# ```bash
# campux is best channel
# ```

# %%
# Write code here
l = [['c', 'a', 'm', 'p', 'u', 'x'], ['i', 's'], ['b', 'e', 's', 't'], ['c', 'h', 'a', 'n', 'n', 'e', 'l']]
l1 = []
for  i in l:
  l1.append("".join(i))
print(" ".join("".join(i) for i in l))
# Out:
# campux is best channel

# %% [markdown]
# ### `Problem 10:` Add Space between Potential Words.
#
# **Example:**
#
# Input:
#
# ```bash
# ['campusxIs', 'bestFor', 'dataScientist']
# ```
#
# Output:
# ```bash
# ['campusx Is', 'best For', 'data Scientist']
# ```

# %%
# Code here
l = ['campusxIs', 'bestFor', 'dataScientist']
l1 = []

for i in l:
  temp = [[]]
  l2 = []

  for c in i:

    if c.isupper():
      temp.append([])

    temp[-1].append(c)


  for i in temp:
    l2.append("".join(i))


  l1.append(" ".join(l2))

l1
# Out:
# ['campusx Is', 'best For', 'data Scientist']

# %% [markdown]
# ### `Problem 11:` Write a program that can perform union operation on 2 lists
#
# **Example:**
#
# Input:
#
# ```bash
# [1,2,3,4,5,1]
# [2,3,5,7,8]
# ```
#
# Output:
# ```bash
# [1,2,3,4,5,7,8]
# ```

# %%
# Write code here
l1 = [1,2,3,4,5,1]
l2 = [2,3,5,7,8]

l =[]
for i in l1:
  if i not in l:
    l.append(i)

for i in l2:
  if i not in l:
    l.append(i)

l
# Out:
# [1, 2, 3, 4, 5, 7, 8]

# %% [markdown]
# ### `Problem 12:` Write a program that can find the max number of each row of a matrix
#
# **Example:**
#
# Input:
#
# ```bash
# [[1,2,3],[4,5,6],[7,8,9]]
# ```
#
# Output:
# ```bash
# [3,6,9]
# ```

# %%
# Write code here
l = [[1,2,3],[4,5,6],[7,8,9]]
[max(row) for row in l]
# Out:
# [3, 6, 9]

# %% [markdown]
# ### `Problem 13:` Write a list comprehension to print the following matrix
#
# [[0, 1, 2], [3, 4, 5], [6, 7, 8]]

# %%
# Write code here
[[i for i in range(3)]] + [[j for j in range(3,6) ] ] + [[k for k in range(6,9)]]
# Out:
# [[0, 1, 2], [3, 4, 5], [6, 7, 8]]

# %%
[[j + 3*i for j in range(3)] for i in range(0,3)]
# Out:
# [[0, 1, 2], [3, 4, 5], [6, 7, 8]]

# %%
l1 = []
for i in range(0,3):
  l = []
  for j in range(0,3):
    l.append(3*i + j)

  l1.append(l)

l1
# Out:
# [[0, 1, 2], [3, 4, 5], [6, 7, 8]]

# %% [markdown]
# ### `Problem 14:` Write a list comprehension that can transpose a given matrix
#
# matrix = [<br>
#   [1,2,3],<br>
#           [4,5,6],<br>
#           [7,8,9]<br>]<br>
#
# [1, 4, 7]<br>
# [2, 5, 8]<br>
# [3, 6, 9]<br>

# %%
# Write code here
matrix = [
[1,2,3],
[4,5,6],
[7,8,9]
]

n_m = []

for i in range(0,3):
  l = []
  for j in range(0,3):
    l.append(matrix[j][i])

  n_m.append(l)

print(n_m)

[[matrix[j][i] for j in range(0,3)] for i in range(0,3)]
# Out:
# [[1, 4, 7], [2, 5, 8], [3, 6, 9]]
# [[1, 4, 7], [2, 5, 8], [3, 6, 9]]

# %% [markdown]
# ### `Problem 15:` Write a list comprehension that can flatten a nested list
#
# Input<br>
# matrix = [<br>
#   [1,2,3],<br>
#           [4,5,6],<br>
#           [7,8,9]<br>]<br>
#
# Output:<br>
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
# Write code here
matrix = [
[1,2,3],
[4,5,6],
[7,8,9]
]

l = []
for i in range(0,3):
  for j in range(0,3):
    l.append(matrix[i][j])

[item for row in matrix for item in row]
l
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
a = [[1, 2], [3, 4], [5, 6]]

# Use list comprehension to flatten the 2D list into a 1D list
[i for j in a for i in j]
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
a = [1,2,3]
b = a

a.append(4)
print(a)
print(b)
# Out:
# [1, 2, 3, 4]
# [1, 2, 3, 4]

# %%
a = (1,2,3)
b = a

a  = a + (4,)
print(a)
print(b)
# Out:
# (1, 2, 3, 4)
# (1, 2, 3)
